# %% [markdown]
# ## Generate Cities List

# %%
#Importing Dependencies
import pandas as pd
import numpy as np
import json
import requests
import gmaps
import gmaps
gkey = "AIzaSyDvPs_H7JqgW9MCF38qOWaTQfR655F_xRI"
# Access maps with unique API key
gmaps.configure(api_key=gkey)

# %%
Calendar_Summary_df = pd.read_csv("../Dataset/calendar_summary.csv")
Listings_df = pd.read_csv("../Dataset/listings.csv")
Listings_Summary_df = pd.read_csv("../Dataset/listings_summary.csv")
Reviews_df = pd.read_csv("../Dataset/reviews.csv")
Reviews_Summary = pd.read_csv("../Dataset/reviews_summary.csv")

# %%
location_data=Listings_df.loc[:,["id","name","latitude","longitude","price"]]
location_data.tail()
# Out:
#              id                                               name   latitude  \
# 22547  29856708       Cozy Apartment right in the center of Berlin  52.533865
# 22548  29857108             Altbau/ Schöneberger Kiez / Schlafsofa  52.496211
# 22549  29864272   Artists loft with garden in the center of Berlin  52.531800
# 22550  29866805              Room for two with private shower / WC  52.520802
# 22551  29867352  Sunny, modern and cozy flat in Berlin Neukölln :)  52.473762
#
#        longitude  price
# 22547  13.400731     60
# 22548  13.341738     20
# 22549  13.411999     85
# 22550  13.378688     99
# 22551  13.424447     45

# %%
locations=location_data[["latitude","longitude"]]
locations.head()
# Out:
#     latitude  longitude
# 0  52.534537  13.402557
# 1  52.548513  13.404553
# 2  52.534996  13.417579
# 3  52.498855  13.349065
# 4  52.543157  13.415091

# %%
# Customize the size of the figure
figure_layout = {
    'width': '800px',
    'height': '600px',
    'border': '1px solid black',
    'padding': '3px',
}

# %%
#The most expensive places
weights=location_data["price"]
fig=gmaps.figure()
reviews_am=gmaps.heatmap_layer(locations,weights=weights,point_radius=13)
fig.add_layer(reviews_am)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
target_city = "Berlin, Germany"
# Build the endpoint URL
target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(target_city, gkey)
response = requests.get(target_url).json()

# %%
api_key='moaFf5l2qja2rA6JbkiB4At_j9jrpUaQVEc7rAnmDDfIlE-D4AtVRhR5Fd4MgQ7ze14urW63I34FrfxWivyONkpDF9GS8ZE1rda1X0AMrIpYGcxDUOh5gapzyG6IXXYx'
headers = {'Authorization': 'Bearer %s' % api_key}

# %%
url='https://api.yelp.com/v3/businesses/search' 
params_rest = {'term':'restaurant','location':'Berlin'}

# %%
# Making a get request to the API
data=requests.get(url, params=params_rest, headers=headers).json()
data
# Out:
# {'businesses': [{'id': '8uBE9ZgfZOM2z_Rllw478Q',
#    'alias': 'stadtklause-berlin',
#    'name': 'Stadtklause',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vqFLzToYyFfAoYKlBRq0jA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stadtklause-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 166,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.504779, 'longitude': 13.380618},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Bernburger Str. 35',
#     'address2': '',
#     'address3': None,
#     'city': 'Berlin',
#     'zip_code': '10963',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Bernburger Str. 35', '10963 Berlin', 'Germany']},
#    'phone': '+493051056381',
#    'display_phone': '+49 30 51056381',
#    'distance': 2205.244050414826},
#   {'id': 'lrADfCYffCllBbJHBgqiIw',
#    'alias': 'spätzle-club-berlin',
#    'name': 'Spätzle Club',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qYKw4UoPYQoR7yBJ1E8K8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sp%C3%A4tzle-club-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 47,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'swabian', 'title': 'Swabian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.51055, 'longitude': 13.40242},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Seydelstr. 2',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10117',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Seydelstr. 2', '10117 Berlin', 'Germany']},
#    'phone': '+493020143139',
#    'display_phone': '+49 30 20143139',
#    'distance': 2411.1721630755546},
#   {'id': 'zoqrQLulC-weIVB83OIc4Q',
#    'alias': 'elefant-berlin',
#    'name': 'Elefant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/D6-sJ4_5N0XzQEx9tSgxVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/elefant-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 154,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.4989484, 'longitude': 13.3453693},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Fuggerstr. 18',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10777',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Fuggerstr. 18', '10777 Berlin', 'Germany']},
#    'phone': '+493023607346',
#    'display_phone': '+49 30 23607346',
#    'distance': 3502.052178173731},
#   {'id': 'ncRxW86sU1aPtqeAMwaqmg',
#    'alias': 'brauereigaststätte-leibhaftig-berlin',
#    'name': 'Brauereigaststätte Leibhaftig',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Uw8hl1JCJ2K-2-oURInlMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brauereigastst%C3%A4tte-leibhaftig-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 82,
#    'categories': [{'alias': 'breweries', 'title': 'Breweries'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 52.53154, 'longitude': 13.41701},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Metzer Str. 30',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10405',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Metzer Str. 30', '10405 Berlin', 'Germany']},
#    'phone': '+493054815039',
#    'display_phone': '+49 30 54815039',
#    'distance': 2894.6086490949574},
#   {'id': 'vCfzL71ng0wuJRdw59DzGw',
#    'alias': 'scheers-schnitzel-berlin',
#    'name': 'Scheers Schnitzel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cKeVjtHC_Ym46L-ySbGkmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scheers-schnitzel-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 162,
#    'categories': [{'alias': 'schnitzel', 'title': 'Schnitzel'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.5028281535678,
#     'longitude': 13.4471690196963},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Warschauer Platz 18',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10245',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Warschauer Platz 18', '10245 Berlin', 'Germany']},
#    'phone': '+4915788948011',
#    'display_phone': '+49 1578 8948011',
#    'distance': 5389.033604502349},
#   {'id': 'JtIJESqexMTtznNchqaG0g',
#    'alias': 'mezem-berlin',
#    'name': 'Mezem',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mlBOeFG8EodlG1_9bRN3Eg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mezem-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 38,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 52.50629, 'longitude': 13.311274},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Kantstr. 124',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10625',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Kantstr. 124', '10625 Berlin', 'Germany']},
#    'phone': '+4917683220425',
#    'display_phone': '+49 176 83220425',
#    'distance': 4811.574286216521},
#   {'id': 'uR7wsySeBtVySv9QO8_hgg',
#    'alias': 'weingalerie-und-café-nö-berlin',
#    'name': 'Weingalerie und Café NÖ!',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bvOhMFp4zzA5vAjMU6kSFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/weingalerie-und-caf%C3%A9-n%C3%B6-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 132,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'flatbread', 'title': 'Flatbread'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.51327, 'longitude': 13.38625},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Glinkastr. 23',
#     'address2': None,
#     'address3': None,
#     'city': 'Berlin',
#     'zip_code': '10117',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Glinkastr. 23', '10117 Berlin', 'Germany']},
#    'phone': '+49302010871',
#    'display_phone': '+49 30 2010871',
#    'distance': 1418.375690635572},
#   {'id': 'vs3J4zfbThn0_5w2Q5Mfuw',
#    'alias': 'schlögls-berlin',
#    'name': "Schlögl's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1yCG-K5HWYfPtej0CEHkKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/schl%C3%B6gls-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 73,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'beergarden', 'title': 'Beer Garden'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.5213, 'longitude': 13.406281},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Karl-Liebknecht-Str. 9',
#     'address2': '',
#     'address3': None,
#     'city': 'Berlin',
#     'zip_code': '10178',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Karl-Liebknecht-Str. 9', '10178 Berlin', 'Germany']},
#    'phone': '+49302411221',
#    'display_phone': '+49 30 2411221',
#    'distance': 2087.1623064697733},
#   {'id': 'F2HUfsf0sBzkjXWiM93ymg',
#    'alias': 'mustafas-gemüse-kebap-berlin-3',
#    'name': 'Mustafas Gemüse Kebap',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZNGf-CMpNZ1XktzyFIvGSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mustafas-gem%C3%BCse-kebap-berlin-3?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 1090,
#    'categories': [{'alias': 'foodstands', 'title': 'Food Stands'},
#     {'alias': 'kebab', 'title': 'Kebab'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.493825, 'longitude': 13.387869},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Mehringdamm 32',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10961',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Mehringdamm 32', '10961 Berlin', 'Germany']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3495.47294892962},
#   {'id': 'w4Rn3wpEsIU2U5h0D0CK8Q',
#    'alias': 'gasthaus-krombach-berlin',
#    'name': 'Gasthaus Krombach',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/S4YZt5P6zbCRzgruJD-xBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gasthaus-krombach-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 98,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.5021160894522,
#     'longitude': 13.3284872202378},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Meinekestr. 4',
#     'address2': None,
#     'address3': None,
#     'city': 'Berlin',
#     'zip_code': '10719',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Meinekestr. 4', '10719 Berlin', 'Germany']},
#    'phone': '+49308818602',
#    'display_phone': '+49 30 8818602',
#    'distance': 4051.3252867499345},
#   {'id': 'jIddBhydYQEOECaa199Hag',
#    'alias': 'cocolo-ramen-berlin',
#    'name': 'Cocolo Ramen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/F32khCZAnrKmR73ILedcag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cocolo-ramen-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 290,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.52718, 'longitude': 13.39934},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Gipsstr. 3',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10119',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Gipsstr. 3', '10119 Berlin', 'Germany']},
#    'phone': '+493098339073',
#    'display_phone': '+49 30 98339073',
#    'distance': 1612.2813770372095},
#   {'id': 'zoGKin7W8L3uyXeXlvc5gg',
#    'alias': 'schnitzelei-mitte-berlin',
#    'name': 'Schnitzelei Mitte',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-xVaR6uTzjpCaap387u0-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/schnitzelei-mitte-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 40,
#    'categories': [{'alias': 'schnitzel', 'title': 'Schnitzel'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.528464, 'longitude': 13.387325},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': 'Chausseestr. 8',
#     'address2': '',
#     'address3': 'Hinterhof',
#     'city': 'Berlin',
#     'zip_code': '10115',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Chausseestr. 8',
#      'Hinterhof',
#      '10115 Berlin',
#      'Germany']},
#    'phone': '+493032519422',
#    'display_phone': '+49 30 32519422',
#    'distance': 898.0743506015705},
#   {'id': 'cq-jjm28Xv8oNVEZLQ5N-g',
#    'alias': 'yarok-berlin',
#    'name': 'Yarok',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8oXTW1WSb8KhwUBz5TnZAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yarok-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 166,
#    'categories': [{'alias': 'syrian', 'title': 'Syrian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.5283244, 'longitude': 13.3920916},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Torstr. 195',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10115',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Torstr. 195', '10115 Berlin', 'Germany']},
#    'phone': '+493095628703',
#    'display_phone': '+49 30 95628703',
#    'distance': 1182.0239454983403},
#   {'id': '6FRBE6pV5tv8n_LmQEvMpg',
#    'alias': 'boulevard-friedrichstrasse-berlin',
#    'name': 'Boulevard Friedrichstrasse',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/alFce-nvmvNLPIEjnBF30g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boulevard-friedrichstrasse-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 59,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.52312, 'longitude': 13.38848},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Friedrichstr. 106 C',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10117',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Friedrichstr. 106 C', '10117 Berlin', 'Germany']},
#    'phone': '+49302833437',
#    'display_phone': '+49 30 2833437',
#    'distance': 863.438188942628},
#   {'id': 'drEchpfmX4DnIhIAMOwLcg',
#    'alias': 'clärchens-ballhaus-berlin-2',
#    'name': 'Clärchens Ballhaus',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/80nW9YAKnElm6YKilblHkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cl%C3%A4rchens-ballhaus-berlin-2?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 213,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'beergarden', 'title': 'Beer Garden'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.52667, 'longitude': 13.39679},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Auguststr. 24',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10117',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Auguststr. 24', '10117 Berlin', 'Germany']},
#    'phone': '+49302829295',
#    'display_phone': '+49 30 2829295',
#    'distance': 1438.6748310560922},
#   {'id': 'HFajim9qjlb3vSqnpR96FQ',
#    'alias': 'rotisserie-weingrün-berlin',
#    'name': 'Rotisserie Weingrün',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Gn5XWWYguyjqgiuTkXqjAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rotisserie-weingr%C3%BCn-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 101,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'german', 'title': 'German'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.5126768, 'longitude': 13.4034261},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': 'Gertraudenstr. 10 - 12',
#     'address2': None,
#     'address3': None,
#     'city': 'Berlin',
#     'zip_code': '10178',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Gertraudenstr. 10 - 12', '10178 Berlin', 'Germany']},
#    'phone': '+493020621900',
#    'display_phone': '+49 30 20621900',
#    'distance': 2275.7622003219517},
#   {'id': '0f3-k1Hyu6__ajXjRpDbCg',
#    'alias': 'volver-berlin',
#    'name': 'Volver',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rqtK5ZOfTAGS6eyQFayMRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/volver-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 63,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.52228, 'longitude': 13.37987},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Luisenstr. 41',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10117',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Luisenstr. 41', '10117 Berlin', 'Germany']},
#    'phone': '+493027572164',
#    'display_phone': '+49 30 27572164',
#    'distance': 355.7619922746784},
#   {'id': 'jHexJKIMOZ4B0v_Ae1OJxw',
#    'alias': 'jolly-berlin',
#    'name': 'Jolly',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bQLInILW5xrk-q7IjNJ7XA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jolly-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 79,
#    'categories': [{'alias': 'panasian', 'title': 'Pan Asian'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.52048, 'longitude': 13.3944},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Kupfergraben 4/4A',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10117',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Kupfergraben 4/4A', '10117 Berlin', 'Germany']},
#    'phone': '+493020059500',
#    'display_phone': '+49 30 20059500',
#    'distance': 1328.2168899700594},
#   {'id': 'yAhYpg2GGeEUV2Li7HOp8g',
#    'alias': 'momotaro-tavern-berlin',
#    'name': 'Momotaro Tavern',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_dlFHwDjxj6jcSHMj7y6Ig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/momotaro-tavern-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 47,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.521213, 'longitude': 13.4096765920655},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Panoramastr. 1 A',
#     'address2': None,
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10178',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Panoramastr. 1 A', '10178 Berlin', 'Germany']},
#    'phone': '+4915203708888',
#    'display_phone': '+49 1520 3708888',
#    'distance': 2315.5159976568266},
#   {'id': 'wNZzTEy8NEh-YNvlcNRqbQ',
#    'alias': 'schleusenkrug-berlin',
#    'name': 'Schleusenkrug',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qUWYd24Xq77ZOkMtaG6MDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/schleusenkrug-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 185,
#    'categories': [{'alias': 'divebars', 'title': 'Dive Bars'},
#     {'alias': 'beergarden', 'title': 'Beer Garden'},
#     {'alias': 'german', 'title': 'German'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.511297851942, 'longitude': 13.3360719306885},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Müller-Breslau-Str. 14 b',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10623',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Müller-Breslau-Str. 14 b',
#      '10623 Berlin',
#      'Germany']},
#    'phone': '+49303139909',
#    'display_phone': '+49 30 3139909',
#    'distance': 3060.7065299840983}],
#  'total': 7400,
#  'region': {'center': {'longitude': 13.3758544921875,
#    'latitude': 52.524398250121365}}}

# %%
name_list=[]
rating=[]
lat_r=[]
lng_r=[]
for i in range(0,len(data['businesses'])):
    name_list.append(data['businesses'][i]['name'])
    rating.append(data['businesses'][i]['rating'])
    lat_r.append(data['businesses'][i]['coordinates']['latitude'])
    lng_r.append(data['businesses'][i]['coordinates']['longitude'])
    
df_rest=pd.DataFrame({"name_rest":name_list,"rating_rest":rating,"lat_rest":lat_r,"lng_rest":lng_r})
marker_locations_rest = list(zip(df_rest["lat_rest"],df_rest['lng_rest']))
df_rest.head()
# Out:
#                        name_rest  rating_rest   lat_rest   lng_rest
# 0                    Stadtklause          4.5  52.504779  13.380618
# 1                   Spätzle Club          4.5  52.510550  13.402420
# 2                        Elefant          4.5  52.498948  13.345369
# 3  Brauereigaststätte Leibhaftig          5.0  52.531540  13.417010
# 4              Scheers Schnitzel          4.5  52.502828  13.447169

# %%
params_cafe = {'term':'cafe','location':'Berlin'}
data=requests.get(url, params=params_cafe, headers=headers).json()
data
# Out:
# {'businesses': [{'id': '_n0Awcf8FFjXBJaCgXXROw',
#    'alias': 'café-bondi-berlin-2',
#    'name': 'Café Bondi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/T-sLeBvMahYCoumsa9Jh8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-bondi-berlin-2?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 102,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.53034261696, 'longitude': 13.38763160899},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Eichendorffstr. 6',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10115',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Eichendorffstr. 6', '10115 Berlin', 'Germany']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1035.2026097377952},
#   {'id': 'cGF_xY6poO6DQuvs2twMzw',
#    'alias': 'father-carpenter-coffee-brewers-berlin',
#    'name': 'Father Carpenter Coffee Brewers',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/z5RbKayuU6tIHqH8pf7Rvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/father-carpenter-coffee-brewers-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 80,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.52478, 'longitude': 13.40677},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Muenzstr. 21',
#     'address2': '1. Hof',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10178',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Muenzstr. 21', '1. Hof', '10178 Berlin', 'Germany']},
#    'phone': '+493040044289',
#    'display_phone': '+49 30 40044289',
#    'distance': 2077.1062250289615},
#   {'id': 'jmUSGwEatWoQBIVJmgLzNQ',
#    'alias': 'oslo-kaffebar-berlin',
#    'name': 'Oslo Kaffebar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5pXMYpRVAct4fwnJUX-B6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oslo-kaffebar-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 90,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.531044, 'longitude': 13.3868},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Eichendorffstr. 13',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10115',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Eichendorffstr. 13', '10115 Berlin', 'Germany']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1042.3798287975364},
#   {'id': 'JCkiG_gEVjJrtHrZ91Z8qQ',
#    'alias': '1900-café-berlin',
#    'name': '1900 Café',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LBbhYQdEYXIZi-9D4Qa2uQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/1900-caf%C3%A9-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 181,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.50395, 'longitude': 13.32246},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Knesebeckstr. 76',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10623',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Knesebeckstr. 76', '10623 Berlin', 'Germany']},
#    'phone': '+493088715871',
#    'display_phone': '+49 30 88715871',
#    'distance': 4261.96538866265},
#   {'id': 'eM7-PbaO2WaI7DUyIXdtZQ',
#    'alias': 'ormado-kaffeehaus-berlin',
#    'name': 'Ormado Kaffeehaus',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qRgB3cYj68zOAJEiXO9new/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ormado-kaffeehaus-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.51023, 'longitude': 13.50133},
#    'transactions': [],
#    'location': {'address1': 'Einbecker Str. 18',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10317',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Einbecker Str. 18', '10317 Berlin', 'Germany']},
#    'phone': '+4917685589190',
#    'display_phone': '+49 176 85589190',
#    'distance': 8628.623819173756},
#   {'id': 'Q0DR4nk26-9-XTNs_tyGuw',
#    'alias': 'five-elephant-berlin',
#    'name': 'Five Elephant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PjislXlXqctDrfgOwBfR6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/five-elephant-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 126,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.49341, 'longitude': 13.43829},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Reichenberger Str. 101',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10999',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Reichenberger Str. 101', '10999 Berlin', 'Germany']},
#    'phone': '+493096081527',
#    'display_phone': '+49 30 96081527',
#    'distance': 5452.294355170434},
#   {'id': '__77YUpqhvreU4YqxsE69g',
#    'alias': 'double-eye-berlin',
#    'name': 'Double Eye',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JUmrp28reErVCU0n49pOPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/double-eye-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 193,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.487950855358, 'longitude': 13.3540870249271},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Akazienstr. 22',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10823',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Akazienstr. 22', '10823 Berlin', 'Germany']},
#    'phone': '+491794566960',
#    'display_phone': '+49 179 4566960',
#    'distance': 4312.233368197723},
#   {'id': 'kgt8geH9oYFGKXOqDgozDg',
#    'alias': 'westberlin-berlin',
#    'name': 'Westberlin',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZIKwbLPIhLnlwdTvuxeewg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/westberlin-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 94,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.505658, 'longitude': 13.390464},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Friedrichstr. 215',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10969',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Friedrichstr. 215', '10969 Berlin', 'Germany']},
#    'phone': '+493025922745',
#    'display_phone': '+49 30 25922745',
#    'distance': 2304.993035525553},
#   {'id': 'nZk1LCfLwFF-Rh2ErwhXcQ',
#    'alias': 'isla-coffee-berlin',
#    'name': 'isla coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/scwAgI86_WFTtTS1m18jvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/isla-coffee-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 8,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.48028, 'longitude': 13.42497},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Hermannstr. 37',
#     'address2': '',
#     'address3': None,
#     'city': 'Berlin',
#     'zip_code': '12049',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Hermannstr. 37', '12049 Berlin', 'Germany']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5915.5635640270875},
#   {'id': 'KdgW4w3Q7i7gv57rnLQc2Q',
#    'alias': 'schiller-backstube-deli-berlin',
#    'name': 'Schiller Backstube Deli',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dsrMqKDnkQJaDD0DKsc19A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/schiller-backstube-deli-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 8,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.5106700962356,
#     'longitude': 13.3755450031154},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Inge-Beisheim-Platz 2',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10785',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Inge-Beisheim-Platz 2', '10785 Berlin', 'Germany']},
#    'phone': '+493025792392',
#    'display_phone': '+49 30 25792392',
#    'distance': 1526.643006250551},
#   {'id': 'CPjSn7dFNcC10VhHa9sqZA',
#    'alias': 'steel-vintage-bikes-café-berlin-3',
#    'name': 'Steel Vintage Bikes Café',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oXep6cP4LJ60YrxP9iV5ew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/steel-vintage-bikes-caf%C3%A9-berlin-3?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 41,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.51254, 'longitude': 13.38211},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Wilhelmstr. 91',
#     'address2': '',
#     'address3': None,
#     'city': 'Berlin',
#     'zip_code': '10117',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Wilhelmstr. 91', '10117 Berlin', 'Germany']},
#    'phone': '+493020623877',
#    'display_phone': '+49 30 20623877',
#    'distance': 1384.844689975583},
#   {'id': 'Eobze0Xon9szj_2nj7BrUQ',
#    'alias': 'factory-girl-berlin-2',
#    'name': 'FACTORY GIRL',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fc4yophfw-E5TWyIf7Qyiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/factory-girl-berlin-2?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 255,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.527302, 'longitude': 13.398852},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Auguststr. 29',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10119',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Auguststr. 29', '10119 Berlin', 'Germany']},
#    'phone': '+493033850062',
#    'display_phone': '+49 30 33850062',
#    'distance': 1588.9623906143374},
#   {'id': 'gYt8OaT4YGLYZHO13tCB_w',
#    'alias': 'chapter-one-berlin-2',
#    'name': 'Chapter One',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pS7V0RmE5S2-1i_mJ3Fs9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chapter-one-berlin-2?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 50,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.48979, 'longitude': 13.39583},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Mittenwalder Str. 30',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10961',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Mittenwalder Str. 30', '10961 Berlin', 'Germany']},
#    'phone': '+493025922799',
#    'display_phone': '+49 30 25922799',
#    'distance': 4076.2483940946186},
#   {'id': '2twC9QYvpzIACsTMgZM9Kg',
#    'alias': 'maxway-coffee-berlin',
#    'name': 'Maxway Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nicPwPkBk_dwhksO0AGGsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maxway-coffee-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 39,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.497631072998, 'longitude': 13.3546829223633},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Maaßenstr. 13',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10777',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Maaßenstr. 13', '10777 Berlin', 'Germany']},
#    'phone': '+493068079868',
#    'display_phone': '+49 30 68079868',
#    'distance': 3303.2723179345085},
#   {'id': 'b6_gYDfuTQEGK9-kIQ1trA',
#    'alias': 'einstein-berlin',
#    'name': 'Einstein',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bNMJ7IdhktCb7OYqce5CTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/einstein-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 155,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.5171673727115,
#     'longitude': 13.3858557611326},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': 'Unter den Linden 42',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10117',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Unter den Linden 42', '10117 Berlin', 'Germany']},
#    'phone': '+49302043632',
#    'display_phone': '+49 30 2043632',
#    'distance': 1050.887955311698},
#   {'id': '384DIylseXUA14DUG-VWHQ',
#    'alias': 'auf-der-suche-nach-dem-verlorenen-glück-berlin',
#    'name': 'Auf der Suche nach dem verlorenen Glück',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TvM1JCiJ9Kz6oZpZah8oZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/auf-der-suche-nach-dem-verlorenen-gl%C3%BCck-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 74,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.54911, 'longitude': 13.3611799},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Nazarethkirchstr. 43',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '13347',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Nazarethkirchstr. 43', '13347 Berlin', 'Germany']},
#    'phone': '+493053080113',
#    'display_phone': '+49 30 53080113',
#    'distance': 2925.7198034245375},
#   {'id': '2OVzfshBWQudko5MlbglEw',
#    'alias': 'coffee-profilers-berlin-2',
#    'name': 'Coffee Profilers',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZWCjfT16z6qVVLBTcZzS6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coffee-profilers-berlin-2?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 16,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 52.51578, 'longitude': 13.45149},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Karl Marx Allee 136',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10243',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Karl Marx Allee 136', '10243 Berlin', 'Germany']},
#    'phone': '+493029777178',
#    'display_phone': '+49 30 29777178',
#    'distance': 5205.731434632434},
#   {'id': 'SDBgiNqMxV4EMjA5gt_VjQ',
#    'alias': 'café-einstein-stammhaus-berlin-4',
#    'name': 'Café Einstein Stammhaus',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bdPM2kF4b0W-6Ztu4r9jxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-einstein-stammhaus-berlin-4?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 192,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.502057, 'longitude': 13.354686},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': 'Kurfürstenstr. 58',
#     'address2': None,
#     'address3': None,
#     'city': 'Berlin',
#     'zip_code': '10785',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Kurfürstenstr. 58', '10785 Berlin', 'Germany']},
#    'phone': '+49302639190',
#    'display_phone': '+49 30 2639190',
#    'distance': 2867.6512241202845},
#   {'id': 'USbVcfJ0aPiNK3ZE-pi2PQ',
#    'alias': 'two-and-two-berlin',
#    'name': 'Two And Two',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CpyiRSQdzDxCBhevNU9btw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/two-and-two-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 22,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'stationery', 'title': 'Cards & Stationery'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.4867128, 'longitude': 13.4310405},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Pannierstr. 6',
#     'address2': '',
#     'address3': None,
#     'city': 'Berlin',
#     'zip_code': '12047',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Pannierstr. 6', '12047 Berlin', 'Germany']},
#    'phone': '+493053791578',
#    'display_phone': '+49 30 53791578',
#    'distance': 5613.453804690317},
#   {'id': '7J-ajOBcPgfi5BSiughgzQ',
#    'alias': 'schwarzes-café-berlin-2',
#    'name': 'Schwarzes Café',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cd8SpgzMpDmBehGDjMsYRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/schwarzes-caf%C3%A9-berlin-2?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 342,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.5055485333737,
#     'longitude': 13.3240840896645},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Kantstr. 148',
#     'address2': None,
#     'address3': None,
#     'city': 'Berlin',
#     'zip_code': '10623',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Kantstr. 148', '10623 Berlin', 'Germany']},
#    'phone': '+49303138038',
#    'display_phone': '+49 30 3138038',
#    'distance': 4082.35239350956}],
#  'total': 2100,
#  'region': {'center': {'longitude': 13.3758544921875,
#    'latitude': 52.524398250121365}}}

# %%
name_list=[]
rating=[]
lat_r=[]
lng_r=[]
for i in range(0,len(data['businesses'])):
    name_list.append(data['businesses'][i]['name'])
    rating.append(data['businesses'][i]['rating'])
    lat_r.append(data['businesses'][i]['coordinates']['latitude'])
    lng_r.append(data['businesses'][i]['coordinates']['longitude'])
    
df_cafe=pd.DataFrame({"name_cafe":name_list,"rating_cafe":rating,"lat_cafe":lat_r,"lng_cafe":lng_r})
marker_locations_cafe = list(zip(df_cafe["lat_cafe"],df_cafe['lng_cafe']))
df_cafe.head(3)
# Out:
#                          name_cafe  rating_cafe   lat_cafe   lng_cafe
# 0                       Café Bondi          4.5  52.530343  13.387632
# 1  Father Carpenter Coffee Brewers          4.0  52.524780  13.406770
# 2                    Oslo Kaffebar          4.5  52.531044  13.386800

# %%
params_bar = {'term':'bar','location':'Berlin'}
data=requests.get(url, params=params_bar, headers=headers).json()
data
# Out:
# {'businesses': [{'id': 'Ojzt5DTrlDk22tz50ludug',
#    'alias': 'gallery-rooftop-bar-berlin',
#    'name': 'Gallery Rooftop Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/umLJ3wucYw92bj2CQ7sXzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gallery-rooftop-bar-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 52.504494, 'longitude': 13.442135},
#    'transactions': [],
#    'location': {'address1': 'Mühlenstr. 19',
#     'address2': '',
#     'address3': 'Mercedes Platz',
#     'city': 'Berlin',
#     'zip_code': '10243',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Mühlenstr. 19',
#      'Mercedes Platz',
#      '10243 Berlin',
#      'Germany']},
#    'phone': '+49302977206908',
#    'display_phone': '+49 30 2977206908',
#    'distance': 5001.482766239111},
#   {'id': '6ZQWI3ni4OQ_ZAmQ2_9E0Q',
#    'alias': 'monkey-bar-berlin',
#    'name': 'Monkey Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mCQc5agIGEe2wOCuX-8e5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/monkey-bar-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 155,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 52.50558, 'longitude': 13.33793},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': 'Budapester Str. 40',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10787',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Budapester Str. 40', '10787 Berlin', 'Germany']},
#    'phone': '+4930120221210',
#    'display_phone': '+49 30 120221210',
#    'distance': 3316.5156684334825},
#   {'id': 'p_jQTJ9MNYk41wzA9dMSdg',
#    'alias': 'hackendahl-berlin',
#    'name': 'Hackendahl',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/S2yASZL2MiY6mkRUbRSVaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hackendahl-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 15,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.5254130550532,
#     'longitude': 13.3872191534424},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Friedrichstr. 128',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10117',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Friedrichstr. 128', '10117 Berlin', 'Germany']},
#    'phone': '+493068001718',
#    'display_phone': '+49 30 68001718',
#    'distance': 777.0871248271612},
#   {'id': '2DHTR7Xr4ZRafumYkm-dZg',
#    'alias': 'kaschk-berlin',
#    'name': 'Kaschk',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Eig_6Gr0MGH-KMUVhTbTJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kaschk-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 49,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.528252347636, 'longitude': 13.4098520881622},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Linienstr. 40',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10119',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Linienstr. 40', '10119 Berlin', 'Germany']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2339.542798709337},
#   {'id': 'A6NKlosjwFVN6wsNZO7DYg',
#    'alias': 'clash-berlin',
#    'name': 'Clash',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AFoc8UnUoc7gyfhFsZmpGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/clash-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 62,
#    'categories': [{'alias': 'divebars', 'title': 'Dive Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.49203, 'longitude': 13.38856},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Gneisenaustr. 2 a',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10961',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Gneisenaustr. 2 a', '10961 Berlin', 'Germany']},
#    'phone': '+493032526387',
#    'display_phone': '+49 30 32526387',
#    'distance': 3696.259595059536},
#   {'id': 'BnRjJ7ZKDl7RkDZHkD06kA',
#    'alias': 'yaam-berlin',
#    'name': 'YAAM',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/x_vDLaBGGS6nhG7Km3LFbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yaam-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 92,
#    'categories': [{'alias': 'beachbars', 'title': 'Beach Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.50958, 'longitude': 13.4296},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'An der Schillingbrücke 3',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10243',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['An der Schillingbrücke 3',
#      '10243 Berlin',
#      'Germany']},
#    'phone': '+49306151354',
#    'display_phone': '+49 30 6151354',
#    'distance': 4064.9025631519658},
#   {'id': 'orKnWqdFr-Y-jnTw285YHw',
#    'alias': 'mein-haus-am-see-berlin',
#    'name': 'Mein Haus am See',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eCieN-8qY_KwXhIroThFrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mein-haus-am-see-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 161,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.5300561877761,
#     'longitude': 13.4007587070716},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Brunnenstr. 197 - 198',
#     'address2': '',
#     'address3': None,
#     'city': 'Berlin',
#     'zip_code': '10119',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Brunnenstr. 197 - 198', '10119 Berlin', 'Germany']},
#    'phone': '+493023883561',
#    'display_phone': '+49 30 23883561',
#    'distance': 1798.385419739355},
#   {'id': 'K_Jt2s8HZ3k-V6zmAJ3U4A',
#    'alias': 'berlin-capital-club-berlin-2',
#    'name': 'Berlin Capital Club',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/m3GWv3-MEqJufa3eGQfC-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/berlin-capital-club-berlin-2?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 16,
#    'categories': [{'alias': 'social_clubs', 'title': 'Social Clubs'},
#     {'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'german', 'title': 'German'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 52.511899, 'longitude': 13.392809},
#    'transactions': [],
#    'location': {'address1': 'Mohrenstr. 30',
#     'address2': None,
#     'address3': None,
#     'city': 'Berlin',
#     'zip_code': '10117',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Mohrenstr. 30', '10117 Berlin', 'Germany']},
#    'phone': '+49302062976',
#    'display_phone': '+49 30 2062976',
#    'distance': 1802.1501941974766},
#   {'id': 'RrkRe5OzzAhLaG7B-MRN2w',
#    'alias': 'aufsturz-berlin',
#    'name': 'Aufsturz',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/31upcBmTmSqkZ8_36y1zPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aufsturz-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 125,
#    'categories': [{'alias': 'divebars', 'title': 'Dive Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.52501, 'longitude': 13.39205},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Oranienburger Str. 67',
#     'address2': None,
#     'address3': None,
#     'city': 'Berlin',
#     'zip_code': '10117',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Oranienburger Str. 67', '10117 Berlin', 'Germany']},
#    'phone': '+493028047407',
#    'display_phone': '+49 30 28047407',
#    'distance': 1096.8413765808289},
#   {'id': '_l67YfTGFmKSnaCjw8_U3g',
#    'alias': 'kumpelnest-3000-berlin',
#    'name': 'Kumpelnest 3000',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mxgIzw3KF0nHZQWEiIlXQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kumpelnest-3000-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 55,
#    'categories': [{'alias': 'divebars', 'title': 'Dive Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.50308, 'longitude': 13.36641},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Lützowstr. 23',
#     'address2': None,
#     'address3': None,
#     'city': 'Berlin',
#     'zip_code': '10785',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Lützowstr. 23', '10785 Berlin', 'Germany']},
#    'phone': '+49302616918',
#    'display_phone': '+49 30 2616918',
#    'distance': 2456.3503812746358},
#   {'id': '8Eg2DjqabhRpMPt5Sjj04g',
#    'alias': 'klunkerkranich-berlin',
#    'name': 'Klunkerkranich',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LU_sij_xk4znFWZ7u-v-iQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/klunkerkranich-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 117,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.4821600866795, 'longitude': 13.431854},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Karl-Marx-Str. 66',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '12043',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Karl-Marx-Str. 66', '12043 Berlin', 'Germany']},
#    'phone': '+4915124504255',
#    'display_phone': '+49 1512 4504255',
#    'distance': 6035.368782372635},
#   {'id': 'U2IYUmmdg_K8MKouubspTw',
#    'alias': 'times-bar-berlin',
#    'name': 'Times Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UP8B3aJ8R5A6XKD7-jprNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/times-bar-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 12,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.50616, 'longitude': 13.3277699},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': 'Fasanenstr. 9-10',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10623',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Fasanenstr. 9-10', '10623 Berlin', 'Germany']},
#    'phone': '+4930311030',
#    'display_phone': '+49 30 311030',
#    'distance': 3839.743137387115},
#   {'id': 'DVxfHqMq2-itSC8mZfco0w',
#    'alias': 'goldfisch-bar-berlin',
#    'name': 'Goldfisch Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2lflHX3JSApiHxNn5XQCEQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/goldfisch-bar-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 78,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.5116299, 'longitude': 13.45839},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Grünberger Str. 67',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10245',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Grünberger Str. 67', '10245 Berlin', 'Germany']},
#    'phone': '+4915122630823',
#    'display_phone': '+49 1512 2630823',
#    'distance': 5752.422209291712},
#   {'id': 'HYDyuCKWN1lxLgskbed0Dw',
#    'alias': 'nemo-berlin',
#    'name': 'Nemo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LfCtDmS-2mp6yhFNPo98Rw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nemo-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 26,
#    'categories': [{'alias': 'divebars', 'title': 'Dive Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.53911, 'longitude': 13.40772},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Oderberger Str. 46',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10435',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Oderberger Str. 46', '10435 Berlin', 'Germany']},
#    'phone': '+49304481959',
#    'display_phone': '+49 30 4481959',
#    'distance': 2683.589787682899},
#   {'id': 'pUXxciCPoqdgZMq_Wt86mA',
#    'alias': '925-lounge-bar-berlin',
#    'name': '925 Lounge Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/52cDG6Szzdt3wJQ3sKigPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/925-lounge-bar-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'restaurants', 'title': 'Restaurants'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.5132, 'longitude': 13.3939},
#    'transactions': [],
#    'location': {'address1': 'Taubenstr. 19',
#     'address2': None,
#     'address3': None,
#     'city': 'Berlin',
#     'zip_code': '10117',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Taubenstr. 19', '10117 Berlin', 'Germany']},
#    'phone': '+493020187177',
#    'display_phone': '+49 30 20187177',
#    'distance': 1743.9401787593442},
#   {'id': 'w4rBlxUiZrCyIkFLoAHsXw',
#    'alias': 'fairytale-bar-berlin',
#    'name': 'Fairytale Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zCLHPIpftXb-EbwrwzZm5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fairytale-bar-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 14,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.52869, 'longitude': 13.42815},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': 'Am Friedrichshain 24',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10407',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Am Friedrichshain 24', '10407 Berlin', 'Germany']},
#    'phone': '+491702195155',
#    'display_phone': '+49 170 2195155',
#    'distance': 3570.462043796497},
#   {'id': 'GCuyPHaGg_3VKHDij-ibdQ',
#    'alias': 'bar-carlitos-berlin',
#    'name': 'Bar Carlitos',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3BzMtwm6YZtGkmUHr1vpKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-carlitos-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 29,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.5020336548149,
#     'longitude': 13.3048441693115},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Sybelstr. 16',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10629',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Sybelstr. 16', '10629 Berlin', 'Germany']},
#    'phone': '+49303231681',
#    'display_phone': '+49 30 3231681',
#    'distance': 5410.677076691207},
#   {'id': 'P95ROOFWT7vFS4QCmPEv6g',
#    'alias': 'badfish-berlin',
#    'name': 'Badfish',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MRo3kXqPLocPeBpfArKOzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/badfish-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 23,
#    'categories': [{'alias': 'divebars', 'title': 'Dive Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.5465656446461,
#     'longitude': 13.4176453202963},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Stargardenerstr. 14',
#     'address2': '',
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10437',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Stargardenerstr. 14', '10437 Berlin', 'Germany']},
#    'phone': '+493054714788',
#    'display_phone': '+49 30 54714788',
#    'distance': 3750.373684675891},
#   {'id': '30feWhTSVeJElu7PEIFdog',
#    'alias': 'upside-down-bar-berlin',
#    'name': 'Upside Down - Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wx1IIDU3-qVcMGZuyutAmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/upside-down-bar-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.51255, 'longitude': 13.41034},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Wallstr. 70',
#     'address2': None,
#     'address3': '',
#     'city': 'Berlin',
#     'zip_code': '10179',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Wallstr. 70', '10179 Berlin', 'Germany']},
#    'phone': '+4930240620',
#    'display_phone': '+49 30 240620',
#    'distance': 2666.635801646388},
#   {'id': 'YIvtq0rA6_uQPyUHhpDGXg',
#    'alias': 'hildegard-bar-berlin',
#    'name': 'Hildegard Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/a58tx4Blo8h2Y7hc1n3GtA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hildegard-bar-berlin?adjust_creative=_J25TLryw_-9hXruIHF_qQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=_J25TLryw_-9hXruIHF_qQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 52.503178, 'longitude': 13.336635},
#    'transactions': [],
#    'location': {'address1': 'Marburgerstr. 3',
#     'address2': '',
#     'address3': None,
#     'city': 'Berlin',
#     'zip_code': '10789',
#     'country': 'DE',
#     'state': 'BE',
#     'display_address': ['Marburgerstr. 3', '10789 Berlin', 'Germany']},
#    'phone': '+493021963283',
#    'display_phone': '+49 30 21963283',
#    'distance': 3551.2285984370687}],
#  'total': 1900,
#  'region': {'center': {'longitude': 13.3758544921875,
#    'latitude': 52.524398250121365}}}

# %%
name_list=[]
rating=[]
lat_r=[]
lng_r=[]
for i in range(0,len(data['businesses'])):
    name_list.append(data['businesses'][i]['name'])
    rating.append(data['businesses'][i]['rating'])
    lat_r.append(data['businesses'][i]['coordinates']['latitude'])
    lng_r.append(data['businesses'][i]['coordinates']['longitude'])
    
df=pd.DataFrame({"name_bar":name_list,"rating_bar":rating,"lat_bar":lat_r,"lng_bar":lng_r})
df_bar=df.loc[df["rating_bar"]>3.9,:]
marker_locations_bar = list(zip(df_bar["lat_bar"],df_bar['lng_bar']))
df_bar.head()
# Out:
#               name_bar  rating_bar    lat_bar    lng_bar
# 0  Gallery Rooftop Bar         5.0  52.504494  13.442135
# 2           Hackendahl         4.0  52.525413  13.387219
# 3               Kaschk         4.0  52.528252  13.409852
# 4                Clash         4.0  52.492030  13.388560
# 5                 YAAM         4.0  52.509580  13.429600

# %%
fig = gmaps.figure()
reviews_am=gmaps.heatmap_layer(locations,weights=weights,point_radius=15)
fig.add_layer(reviews_am)

markers_rest = gmaps.marker_layer(marker_locations_rest)
fig.add_layer(markers_rest)
markers_bar = gmaps.marker_layer(marker_locations_bar)
fig.add_layer(markers_bar)
markers_cafe = gmaps.marker_layer(marker_locations_cafe)
fig.add_layer(markers_cafe)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#The same data but another view
import gmaps.datasets

bar_df = df_bar[['lat_bar', 'lng_bar']]
cafe_df = df_cafe[['lat_cafe', 'lng_cafe']]
rest_df = df_rest[['lat_rest', 'lng_rest']]

bar_layer = gmaps.symbol_layer(
    bar_df, fill_color='rgba(0, 0, 200, 0.4)',
    stroke_color='rgba(0, 0, 200, 0.4)', scale=5)
cafe_layer = gmaps.symbol_layer(
    cafe_df, fill_color='rgba(0, 0, 200, 0.4)',
    stroke_color='rgba(0, 0, 200, 0.4)', scale=5)
rest_layer = gmaps.symbol_layer(
    rest_df, fill_color='rgba(0, 0, 200, 0.4)',
    stroke_color='rgba(0, 0, 200, 0.4)', scale=5)

fig = gmaps.figure()
reviews_am=gmaps.heatmap_layer(locations,weights=weights,point_radius=15)
fig.add_layer(reviews_am)
fig.add_layer(bar_layer)
fig.add_layer(cafe_layer)
fig.add_layer(rest_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
